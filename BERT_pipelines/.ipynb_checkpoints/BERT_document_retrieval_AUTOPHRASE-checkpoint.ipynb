# %%
from pymilvus import MilvusClient, DataType
from openai import OpenAI, Embedding
from sentence_transformers import SentenceTransformer
import pandas as pd
import time
import numpy as np
import json

# %%
milvus_client = MilvusClient(
    uri="http://localhost:19530"
)

# %%
queries = pd.read_csv("../queries_for_documents.csv").tail(50)

# %%
len(queries)
# Out:
# 50

# %%
### BERT Embeddings
model_name = "sentence-transformers/all-mpnet-base-v2"
# model_name = "all-MiniLM-L6-v2"
model = SentenceTransformer(model_name)
def get_embeddings_from_bert(sentence):
    return model.encode([sentence])[0]
# Out:
# C:\Python311\Lib\site-packages\huggingface_hub\file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
queries.head()
# Out:
#                                                 query  doc_index
# 25  Who are the plaintiffs involved in the Mazzaga...        556
# 26  How much of a hit did Best Buy's stock take af...        302
# 27  How are medicare pricing adjustments affecting...        312
# 28  How much has twitter been devalued since rebra...        314
# 29  What effect is China's imports on crude oil ha...        545

# %%
def compute_score(row, p):

    query, ground_truth_document_id = row["query"], row["doc_index"]
    collection_name = f"yahoo_finance_article_DROPOUT_{int(p * 100)}"
    embedded_query = get_embeddings_from_bert(query)

    start = time.time()
    
    res = milvus_client.search(
        collection_name=collection_name,
        data=[embedded_query],
        limit=5,
        search_params={"metric_type": "IP", "params": {}} # Search parameters
    )
    
    end = time.time()
    exec_time = end - start

    top1 = 1 if ground_truth_document_id in [r["id"] for r in res[0]][:1] else 0
    top3 = 1 if ground_truth_document_id in [r["id"] for r in res[0]][:3] else 0
    top5 = 1 if ground_truth_document_id in [r["id"] for r in res[0]][:5] else 0

    return (top1, top3, top5, exec_time)

# %%
for p in [0, 0.1, 0.3, 0.5, 0.7, 0.9]:
    # queries["scores"] = queries["query"].map(lambda x: compute_score(x, p))
    queries[f"scores_{p}"] = queries.apply(lambda x: compute_score(x, p), axis=1)

# %%
queries
# Out:
#                                                 query  doc_index  \
# 25  Who are the plaintiffs involved in the Mazzaga...        556
# 26  How much of a hit did Best Buy's stock take af...        302
# 27  How are medicare pricing adjustments affecting...        312
# 28  How much has twitter been devalued since rebra...        314
# 29  What effect is China's imports on crude oil ha...        545
# 30  Why is Brazil looking to make income tax cuts ...         12
# 31  What background checking service do large firm...         25
# 32  How could President-elect Donald Trump's propo...        238
# 33  How is scaled solutions providing value to cli...         70
# 34  How big of a problem was it for Symbotic to de...        121
# 35  How are short and medium inflation outlooks ch...        200
# 36  What is the banking expert financial analysis ...        201
# 37  What are the risks associated with rising leve...        361
# 38  Who is Trump's nomination to replace Jerome Po...        362
# 39  What other AI investment plays are big investo...        391
# 40  What companies in the food industry have been ...        392
# 41  What products is H promising to deliver by the...        432
# 42  What charitable causes is OpenAI contributing ...        434
# 43  Who are the suspects in the cutting of the fib...        439
# 44  Why are homebuilder stocks down as the S&P 500...        460
# 45  Why did NVIDIA's stock not dip significantly a...        462
# 46  Why did NVIDIA stock dip after seeing increase...        470
# 47  How does Microsoft utilize user data to improv...         45
# 48  Have there been any sensitive data leaks withi...         49
# 49  How does Bluesky plan on introducing verified ...         54
# 50  What is Elon Musk's plan for Neuralink in Cana...        277
# 51  Which pharmaceutical stocks are positioned to ...        280
# 52  Berlin's christmas markets looked very differe...        281
# 53  What are the predicted earnings of Kohls after...        283
# 54  What do Trump's tariffs mean for China's econo...        291
# 55  How has the housing market changed in terms of...        139
# 56  How will Donald Trump's pledge to make the US ...        141
# 57  How will Trump's nomination of RFK affect the ...        143
# 58  How will Trump and his nominations for DOGE ch...        144
# 59  What is the FED's outlook on inflation for con...        149
# 60  How is the FED trimming its balance sheet in t...        180
# 61  How does Alberta fighting the Canadian cap on ...        181
# 62  How will Trump's former cabinet fit into the c...        185
# 63  To what extent is BNP Paribas excluding the oi...        186
# 64  What are we seeing reflected in the stock mark...        187
# 65  What companies did Tim Cook meet with in China...        261
# 66  How serious is the DOJ's probe into digicel? I...        269
# 67  What are Amazon and SpaceX challenging the NLR...        573
# 68  What caused HP's weaker-than-expected Personal...         86
# 69  Why is Peabody energy dropping and is it possi...         94
# 70  Why is workday stock dropping even as they pos...        105
# 71  How is Walmart's new approach to DEI affecting...        161
# 72  Why is the dollar weakening and how does this ...        176
# 73  Consumer spending is increasing month over mon...        192
# 74  Why did Trump's tariffs not do much in his fir...        193
#
#                             scores_0                        scores_0.1  \
# 25   (1, 1, 1, 0.012018442153930664)   (1, 1, 1, 0.005983114242553711)
# 26  (1, 1, 1, 0.0058934688568115234)     (0, 1, 1, 0.0039825439453125)
# 27   (1, 1, 1, 0.004968881607055664)   (1, 1, 1, 0.003983974456787109)
# 28   (1, 1, 1, 0.003982067108154297)  (1, 1, 1, 0.0049724578857421875)
# 29   (1, 1, 1, 0.004147529602050781)   (0, 1, 1, 0.004984855651855469)
# 30   (1, 1, 1, 0.003981351852416992)   (1, 1, 1, 0.003983259201049805)
# 31  (1, 1, 1, 0.0040056705474853516)   (1, 1, 1, 0.004980564117431641)
# 32   (0, 1, 1, 0.004981517791748047)    (0, 1, 1, 0.00498652458190918)
# 33   (1, 1, 1, 0.005016326904296875)   (0, 1, 1, 0.005036592483520508)
# 34    (1, 1, 1, 0.00500035285949707)   (1, 1, 1, 0.004492521286010742)
# 35   (1, 1, 1, 0.004002571105957031)  (1, 1, 1, 0.0039997100830078125)
# 36  (0, 1, 1, 0.0049800872802734375)   (0, 0, 0, 0.003969430923461914)
# 37  (1, 1, 1, 0.0039997100830078125)    (0, 1, 1, 0.00502777099609375)
# 38   (1, 1, 1, 0.004981517791748047)   (1, 1, 1, 0.005003690719604492)
# 39   (0, 0, 0, 0.003995180130004883)   (0, 0, 0, 0.005527973175048828)
# 40   (1, 1, 1, 0.005983591079711914)   (1, 1, 1, 0.005474567413330078)
# 41   (0, 1, 1, 0.004000186920166016)   (0, 1, 1, 0.003885507583618164)
# 42   (1, 1, 1, 0.003995418548583984)   (1, 1, 1, 0.004892826080322266)
# 43   (0, 1, 1, 0.004881620407104492)   (0, 1, 1, 0.003983020782470703)
# 44   (0, 1, 1, 0.003998994827270508)   (0, 1, 1, 0.004998207092285156)
# 45   (0, 0, 1, 0.004927635192871094)   (0, 0, 0, 0.003990650177001953)
# 46    (1, 1, 1, 0.00397801399230957)    (0, 0, 1, 0.00788116455078125)
# 47   (1, 1, 1, 0.004052639007568359)   (1, 1, 1, 0.003918170928955078)
# 52    (1, 1, 1, 0.00397491455078125)   (1, 1, 1, 0.004973411560058594)
# 53   (1, 1, 1, 0.003996849060058594)   (1, 1, 1, 0.003893613815307617)
# 54   (1, 1, 1, 0.005007743835449219)  (0, 0, 1, 0.0029811859130859375)
# 55   (1, 1, 1, 0.004974842071533203)    (1, 1, 1, 0.00399327278137207)
# 56   (0, 0, 0, 0.003949165344238281)   (0, 0, 0, 0.004000186920166016)
# 57   (1, 1, 1, 0.004007816314697266)   (1, 1, 1, 0.004001140594482422)
# 58    (1, 1, 1, 0.00600743293762207)   (0, 0, 0, 0.004901409149169922)
# 59  (0, 1, 1, 0.0049839019775390625)   (0, 1, 1, 0.005893707275390625)
# 60   (1, 1, 1, 0.004889965057373047)   (0, 0, 0, 0.004969358444213867)
# 61    (0, 0, 0, 0.00498199462890625)  (0, 0, 0, 0.0049555301666259766)
# 62   (0, 1, 1, 0.004895210266113281)   (1, 1, 1, 0.004893779754638672)
# 63   (1, 1, 1, 0.003982067108154297)   (1, 1, 1, 0.003981113433837891)
# 64   (0, 0, 0, 0.004883527755737305)    (0, 0, 0, 0.00488591194152832)
# 65   (1, 1, 1, 0.004001140594482422)  (1, 1, 1, 0.0048923492431640625)
# 66  (0, 0, 0, 0.0039823055267333984)   (0, 0, 0, 0.004895925521850586)
# 67   (1, 1, 1, 0.003982067108154297)   (1, 1, 1, 0.004006147384643555)
# 68  (0, 0, 0, 0.0054416656494140625)   (0, 1, 1, 0.004884958267211914)
# 69   (1, 1, 1, 0.005889415740966797)  (0, 0, 0, 0.0032646656036376953)
# 70   (0, 0, 1, 0.004992246627807617)   (1, 1, 1, 0.004898786544799805)
# 71  (0, 0, 0, 0.0049762725830078125)    (0, 0, 0, 0.00537562370300293)
# 72  (0, 0, 0, 0.0039827823638916016)   (0, 0, 0, 0.003867626190185547)
# 73   (0, 0, 0, 0.003894329071044922)   (0, 1, 1, 0.004996776580810547)
# 74   (1, 1, 1, 0.004981040954589844)    (0, 1, 1, 0.00540924072265625)

# %%
scores_percentage = {}

for p in [0, 0.1, 0.3, 0.5, 0.7, 0.9]:
    scores_percentage[str(p)] = tuple(
        sum(values) / len(values) for values in zip(*queries[f'scores_{p}'])
    )

# %%
scores_percentage
# Out:
# {'0': (0.7, 0.86, 0.9, 0.004512143135070801),
#  '0.1': (0.58, 0.8, 0.84, 0.004561066627502441),
#  '0.3': (0.6, 0.86, 0.88, 0.004333887100219726),
#  '0.5': (0.68, 0.8, 0.82, 0.004228873252868652),
#  '0.7': (0.48, 0.6, 0.64, 0.004445037841796875),
#  '0.9': (0.34, 0.54, 0.6, 0.004518542289733887)}

# %%
sums = {}


for p in [0, 0.1, 0.3, 0.5, 0.7, 0.9]:
    sums[str(p)] = tuple(
        sum(values)for values in zip(*queries[f'scores_{p}'])
    )
sums
# Out:
# {'0': (35, 43, 45, 0.22560715675354004),
#  '0.1': (29, 40, 42, 0.22805333137512207),
#  '0.3': (30, 43, 44, 0.21669435501098633),
#  '0.5': (34, 40, 41, 0.21144366264343262),
#  '0.7': (24, 30, 32, 0.22225189208984375),
#  '0.9': (17, 27, 30, 0.22592711448669434)}
